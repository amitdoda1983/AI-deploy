# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle
import requests
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/My Drive/Edureka/flask/Salary_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %%
X.shape
# Out:
# (30, 1)

# %%
y.shape
# Out:
# (30,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.33, 
                                                    random_state = 0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Save the learnt model

# %%
pickle.dump(regressor, open('/content/drive/My Drive/Edureka/flask/model.pkl','wb'))

# %%
y_pred = regressor.predict(X_test)

# %%
# Loading model to compare the results
model = pickle.load(open('/content/drive/My Drive/Edureka/flask/model.pkl','rb'))
print(model.predict([[1.8]]))
# Out:
# [43638.88864165]
